# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeineom12/BaekJoon-practice/blob/main/20251224.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1316번: 그룹 단어 체커

# %% [markdown]
# 그룹 단어란 단어에 존재하는 모든 문자에 대해서, 각 문자가 연속해서 나타나는 경우만을 말한다. 예를 들면, ccazzzzbb는 c, a, z, b가 모두 연속해서 나타나고, kin도 k, i, n이 연속해서 나타나기 때문에 그룹 단어이지만, aabbbccb는 b가 떨어져서 나타나기 때문에 그룹 단어가 아니다.
#
# 단어 N개를 입력으로 받아 그룹 단어의 개수를 출력하는 프로그램을 작성하시오.

# %%
Q1 = int(input())
word = []

for _ in range(Q1) :
    Q2 = input()
    word.append(Q2)
# Out:
# 9
# aaa
# aaazbz
# babb
# aazz
# azbz
# aabbaa
# abacc
# aba
# zzaz

# %%
num = 0
for i in range(len(word)) : # word안에 들어있는 단어 순서
  result = []
  if len(word[i]) == 1 :
    num += 1
    continue
  result.append(word[i][0])
  for j in range(1,len(word[i])) : # 주어진 단어의 알파벳 순서
    s = word[i][j-1] # i번째 단어의 j-1번째 알파벳
    if s != word[i][j] :
      result.append(word[i][j])
    else :
      continue
  if len(result) == len(set(result)) :
    num += 1
print(num)
# Out:
# 2

# %% [markdown]
# ## 2908번: 상수

# %% [markdown]
# 상근이의 동생 상수는 수학을 정말 못한다. 상수는 숫자를 읽는데 문제가 있다. 이렇게 수학을 못하는 상수를 위해서 상근이는 수의 크기를 비교하는 문제를 내주었다. 상근이는 세 자리 수 두 개를 칠판에 써주었다. 그 다음에 크기가 큰 수를 말해보라고 했다.
#
# 상수는 수를 다른 사람과 다르게 거꾸로 읽는다. 예를 들어, 734와 893을 칠판에 적었다면, 상수는 이 수를 437과 398로 읽는다. 따라서, 상수는 두 수중 큰 수인 437을 큰 수라고 말할 것이다.
#
# 두 수가 주어졌을 때, 상수의 대답을 출력하는 프로그램을 작성하시오.

# %%
n1, n2 = input().split()
# Out:
# 839 237

# %%
nm1 = 0
nm2 = 0

for i in range(len(n1)) :
  nm1 += int(n1[i]) * 10**i

for i in range(len(n2)) :
  nm2 += int(n2[i]) * 10**i

if nm1 > nm2 :
  print(nm1)
else :
  print(nm2)
# Out:
# 938
