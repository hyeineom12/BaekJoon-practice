# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeineom12/BaekJoon-practice/blob/main/20260120.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1806번: 부분합

# %% [markdown]
# 10,000 이하의 자연수로 이루어진 길이 N짜리 수열이 주어진다. 이 수열에서 연속된 수들의 부분합 중에 그 합이 S 이상이 되는 것 중, 가장 짧은 것의 길이를 구하는 프로그램을 작성하시오.

# %%
N, S = map(int, input().split())
seq = list(map(int, input().split()))
# Out:
# 10 15
# 5 1 3 5 10 7 4 9 2 8

# %%
left = 0
right = 0
current_sum = 0
min_leg = N+1

while True :
  if right == N :
    break

  current_sum += seq[right]

  if current_sum >= S :
    while current_sum >= S :
      current_sum -= seq[left]
      left += 1
    if min_leg > right - left + 2 :
      min_leg = right - left + 2

  right += 1

if min_leg == N+1 :
  print(0)
else :
  print(min_leg)

# %% [markdown]
# ## 1715번: 카드 정렬하기

# %% [markdown]
# 정렬된 두 묶음의 숫자 카드가 있다고 하자. 각 묶음의 카드의 수를 A, B라 하면 보통 두 묶음을 합쳐서 하나로 만드는 데에는 A+B 번의 비교를 해야 한다. 이를테면, 20장의 숫자 카드 묶음과 30장의 숫자 카드 묶음을 합치려면 50번의 비교가 필요하다.
#
# 매우 많은 숫자 카드 묶음이 책상 위에 놓여 있다. 이들을 두 묶음씩 골라 서로 합쳐나간다면, 고르는 순서에 따라서 비교 횟수가 매우 달라진다. 예를 들어 10장, 20장, 40장의 묶음이 있다면 10장과 20장을 합친 뒤, 합친 30장 묶음과 40장을 합친다면 (10 + 20) + (30 + 40) = 100번의 비교가 필요하다. 그러나 10장과 40장을 합친 뒤, 합친 50장 묶음과 20장을 합친다면 (10 + 40) + (50 + 20) = 120 번의 비교가 필요하므로 덜 효율적인 방법이다.
#
# N개의 숫자 카드 묶음의 각각의 크기가 주어질 때, 최소한 몇 번의 비교가 필요한지를 구하는 프로그램을 작성하시오.

# %%
N = int(input())
card = []
for _ in range(N) :
  card.append(int(input()))
# Out:
# 3
# 10
# 20
# 40

# %%
import heapq

heapq.heapify(card)
result = 0


while len(card) > 1 :
  i = heapq.heappop(card)
  j = heapq.heappop(card)

  s = i + j

  heapq.heappush(card, s)
  result += s


print(result)
# Out:
# 100
